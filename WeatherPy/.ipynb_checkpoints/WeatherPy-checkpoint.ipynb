# %% [markdown]
# # WeatherPy

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from config import key_dict
from pprint import pprint
import scipy.stats as stat
from citipy import citipy
import random
import json

weather_key = key_dict['owm']

# Output file
output_data_file = ".../output_data/cities.csv"

lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# Find lattitude and longitude for random cities
lat_lngs = []
cities = []

# Random lattitude and longitude combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# use exception to ensure that we do not get duplicate cities
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
 
    if city not in cities:
        cities.append(city)
        
len(cities)
# Out:
# 628

# %%
# Confirm list of cities pulled then comment out to take less space
# cities

# %% [markdown]
# ### API Calls

# %%
# New list to contain 
responses_city = []
for city in cities:
    main_url = "http://api.openweathermap.org/data/2.5/weather?"
    query_url = f"{main_url}appid={weather_key}&q="
    try:
        city_data = requests.get(query_url + city).json()
        responses_city.append(city_data)
        print(f"Processing Record for city: {city}")

    except (KeyError):
        print("City information not available")
# Out:
# Processing Record for city: toowoomba
# Processing Record for city: victor harbor
# Processing Record for city: formosa do rio preto
# Processing Record for city: kapaa
# Processing Record for city: arman
# Processing Record for city: sikasso
# Processing Record for city: sumbe
# Processing Record for city: shrigonda
# Processing Record for city: torbay
# Processing Record for city: tsihombe
# Processing Record for city: pochutla
# Processing Record for city: albany
# Processing Record for city: port blair
# Processing Record for city: ushuaia
# Processing Record for city: urfa
# Processing Record for city: san cristobal
# Processing Record for city: vaini
# Processing Record for city: kirundo
# Processing Record for city: iqaluit
# Processing Record for city: hermanus
# Processing Record for city: saskylakh
# Processing Record for city: valls
# Processing Record for city: bluff
# Processing Record for city: arawa
# Processing Record for city: lebu
# Processing Record for city: naze
# Processing Record for city: upernavik
# Processing Record for city: saint george
# Processing Record for city: chapais
# Processing Record for city: touros
# Processing Record for city: rikitea
# Processing Record for city: cape town
# Processing Record for city: punta arenas
# Processing Record for city: costa rica
# Processing Record for city: khatanga
# Processing Record for city: lakatoro
# Processing Record for city: cidreira
# Processing Record for city: beringovskiy
# Processing Record for city: phan rang
# Processing Record for city: aylmer
# Processing Record for city: russell
# Processing Record for city: kavieng
# Processing Record for city: cabo san lucas
# Processing Record for city: vestmanna
# Processing Record for city: aquiraz
# Processing Record for city: campoverde
# Processing Record for city: itarema
# Processing Record for city: mataura
# Processing Record for city: mahibadhoo
# Processing Record for city: dunedin
# Processing Record for city: hobart
# Processing Record for city: georgetown
# Processing Record for city: mouzouras
# Processing Record for city: codrington
# Processing Record for city: atuona
# Processing Record for city: chuy
# Processing Record for city: hilo
# Processing Record for city: busselton
# Processing Record for city: saint-philippe
# Processing Record for city: narsaq
# Processing Record for city: hasaki
# Processing Record for city: xining
# Processing Record for city: umzimvubu
# Processing Record for city: santander jimenez
# Processing Record for city: grindavik
# Processing Record for city: airai
# Processing Record for city: verkhnyaya inta
# Processing Record for city: roald
# Processing Record for city: alofi
# Processing Record for city: sola
# Processing Record for city: kaeo
# Processing Record for city: attawapiskat
# Processing Record for city: rodrigues alves
# Processing Record for city: ca mau
# Processing Record for city: tuatapere
# Processing Record for city: haapiti
# Processing Record for city: taolanaro
# Processing Record for city: kolokani
# Processing Record for city: grand river south east
# Processing Record for city: vila franca do campo
# Processing Record for city: illoqqortoormiut
# Processing Record for city: nadvoitsy
# Processing Record for city: nikolskoye
# Processing Record for city: mar del plata
# Processing Record for city: chardara
# Processing Record for city: sidvokodvo
# Processing Record for city: wencheng
# Processing Record for city: port alfred
# Processing Record for city: port elizabeth
# Processing Record for city: puerto ayora
# Processing Record for city: scarborough
# Processing Record for city: ribeira grande
# Processing Record for city: carnarvon
# Processing Record for city: yellowknife
# Processing Record for city: agua branca
# Processing Record for city: bambous virieux
# Processing Record for city: lorengau
# Processing Record for city: bredasdorp
# Processing Record for city: jamestown
# Processing Record for city: luderitz
# Processing Record for city: tambopata
# Processing Record for city: algiers
# Processing Record for city: ardabil
# Processing Record for city: castro
# Processing Record for city: palabuhanratu
# Processing Record for city: kaitangata
# Processing Record for city: avarua
# Processing Record for city: sioux lookout
# Processing Record for city: shimoda
# Processing Record for city: west bay
# Processing Record for city: jalingo
# Processing Record for city: hualmay
# Processing Record for city: barrow
# Processing Record for city: arraial do cabo
# Processing Record for city: asau
# Processing Record for city: blind river
# Processing Record for city: mahebourg
# Processing Record for city: rantepao
# Processing Record for city: molo
# Processing Record for city: hambantota
# Processing Record for city: nantucket
# Processing Record for city: gemena
# Processing Record for city: mount gambier
# Processing Record for city: luang prabang
# Processing Record for city: dongsheng
# Processing Record for city: nanortalik
# Processing Record for city: qaanaaq
# Processing Record for city: provideniya
# Processing Record for city: yerbogachen
# Processing Record for city: belmonte
# Processing Record for city: aklavik
# Processing Record for city: kisangani
# Processing Record for city: kiama
# Processing Record for city: manbij
# Processing Record for city: antonina
# Processing Record for city: coquimbo
# Processing Record for city: barentsburg
# Processing Record for city: peto
# Processing Record for city: ishigaki
# Processing Record for city: soma
# Processing Record for city: churapcha
# Processing Record for city: east london
# Processing Record for city: tiznit
# Processing Record for city: hirara
# Processing Record for city: pevek
# Processing Record for city: baragua
# Processing Record for city: kuvandyk
# Processing Record for city: bengkulu
# Processing Record for city: lima
# Processing Record for city: yar-sale
# Processing Record for city: buala
# Processing Record for city: port hardy
# Processing Record for city: zyryanka
# Processing Record for city: kushiro
# Processing Record for city: coihaique
# Processing Record for city: sentyabrskiy
# Processing Record for city: sorland
# Processing Record for city: amderma
# Processing Record for city: vila
# Processing Record for city: leshukonskoye
# Processing Record for city: houma
# Processing Record for city: camocim
# Processing Record for city: pavlohrad
# Processing Record for city: hanzhong
# Processing Record for city: new norfolk
# Processing Record for city: barquisimeto
# Processing Record for city: ambilobe
# Processing Record for city: dubti
# Processing Record for city: harqalah
# Processing Record for city: sortland
# Processing Record for city: belushya guba
# Processing Record for city: lompoc
# Processing Record for city: lodeynoye pole
# Processing Record for city: pisco
# Processing Record for city: dingli
# Processing Record for city: brazzaville
# Processing Record for city: kamenskoye
# Processing Record for city: challans
# Processing Record for city: mount isa
# Processing Record for city: portland
# Processing Record for city: vao
# Processing Record for city: maromitsa
# Processing Record for city: ancud
# Processing Record for city: bajil
# Processing Record for city: tasiilaq
# Processing Record for city: vila velha
# Processing Record for city: butaritari
# Processing Record for city: genhe
# Processing Record for city: mirnyy
# Processing Record for city: suluq
# Processing Record for city: vagur
# Processing Record for city: mao
# Processing Record for city: tabory
# Processing Record for city: vaitape
# Processing Record for city: caravelas
# Processing Record for city: andros town
# Processing Record for city: berlevag
# Processing Record for city: olafsvik
# Processing Record for city: cheuskiny
# Processing Record for city: lafayette
# Processing Record for city: tubinskiy
# Processing Record for city: bethel
# Processing Record for city: kendari
# Processing Record for city: nemuro
# Processing Record for city: faya
# Processing Record for city: cairns
# Processing Record for city: buritizeiro
# Processing Record for city: bathsheba
# Processing Record for city: bundaberg
# Processing Record for city: altukhovo
# Processing Record for city: souillac
# Processing Record for city: belyy yar
# Processing Record for city: tiksi
# Processing Record for city: uvarovka
# Processing Record for city: north bend
# Processing Record for city: avera
# Processing Record for city: harrai
# Processing Record for city: marcona
# Processing Record for city: athabasca
# Processing Record for city: egvekinot
# Processing Record for city: sorkjosen
# Processing Record for city: champerico
# Processing Record for city: svetlogorsk
# Processing Record for city: ciechocinek
# Processing Record for city: katherine
# Processing Record for city: igarka
# Processing Record for city: puerto leguizamo
# Processing Record for city: the valley
# Processing Record for city: bambanglipuro
# Processing Record for city: kodiak
# Processing Record for city: dale
# Processing Record for city: lagoa
# Processing Record for city: katsuura
# Processing Record for city: rawson
# Processing Record for city: guerrero negro
# Processing Record for city: zhezkazgan
# Processing Record for city: komsomolskiy
# Processing Record for city: yulara
# Processing Record for city: rasuceni
# Processing Record for city: khorramabad
# Processing Record for city: lavrentiya
# Processing Record for city: kanniyakumari
# Processing Record for city: malayal
# Processing Record for city: morgan city
# Processing Record for city: kruisfontein
# Processing Record for city: cayenne
# Processing Record for city: clyde river
# Processing Record for city: taoudenni
# Processing Record for city: faanui
# Processing Record for city: cabedelo
# Processing Record for city: victoria
# Processing Record for city: pecos
# Processing Record for city: cherskiy
# Processing Record for city: mujiayingzi
# Processing Record for city: coahuayana
# Processing Record for city: christchurch
# Processing Record for city: kysyl-syr
# Processing Record for city: sassandra
# Processing Record for city: ninh binh
# Processing Record for city: stettler
# Processing Record for city: port hedland
# Processing Record for city: maues
# Processing Record for city: tubmanburg
# Processing Record for city: kem
# Processing Record for city: manalongon
# Processing Record for city: mortka
# Processing Record for city: quimper
# Processing Record for city: broken hill
# Processing Record for city: vostok
# Processing Record for city: hamilton
# Processing Record for city: kulu
# Processing Record for city: klyuchi
# Processing Record for city: general roca
# Processing Record for city: husavik
# Processing Record for city: acapulco
# Processing Record for city: moshupa
# Processing Record for city: velyka lepetykha
# Processing Record for city: longyearbyen
# Processing Record for city: ustyuzhna
# Processing Record for city: nisia floresta
# Processing Record for city: marakkanam
# Processing Record for city: lixourion
# Processing Record for city: marzuq
# Processing Record for city: chicama
# Processing Record for city: kailua
# Processing Record for city: ilulissat
# Processing Record for city: foam lake
# Processing Record for city: eureka
# Processing Record for city: dombarovskiy
# Processing Record for city: valley city
# Processing Record for city: fort saint john
# Processing Record for city: samarai
# Processing Record for city: fortuna
# Processing Record for city: henties bay
# Processing Record for city: lake havasu city
# Processing Record for city: kahului
# Processing Record for city: kieta
# Processing Record for city: hofn
# Processing Record for city: mihai bravu
# Processing Record for city: isangel
# Processing Record for city: chimbote
# Processing Record for city: kudymkar
# Processing Record for city: chepareria
# Processing Record for city: flinders
# Processing Record for city: nagato
# Processing Record for city: hithadhoo
# Processing Record for city: appingedam
# Processing Record for city: kerugoya
# Processing Record for city: shenjiamen
# Processing Record for city: ilave
# Processing Record for city: modasa
# Processing Record for city: meulaboh
# Processing Record for city: havre-saint-pierre
# Processing Record for city: coetupo
# Processing Record for city: sarkand
# Processing Record for city: ler
# Processing Record for city: elko
# Processing Record for city: axim
# Processing Record for city: pontes e lacerda
# Processing Record for city: bailen
# Processing Record for city: puerto madryn
# Processing Record for city: chokurdakh
# Processing Record for city: suhut
# Processing Record for city: black diamond
# Processing Record for city: durban
# Processing Record for city: zhigansk
# Processing Record for city: pacific grove
# Processing Record for city: usinsk
# Processing Record for city: huarmey
# Processing Record for city: kuche
# Processing Record for city: ailigandi
# Processing Record for city: werda
# Processing Record for city: hollola
# Processing Record for city: pekan
# Processing Record for city: hearst
# Processing Record for city: pacifica
# Processing Record for city: dikson
# Processing Record for city: faridan
# Processing Record for city: khani
# Processing Record for city: harlingen
# Processing Record for city: nova soure
# Processing Record for city: baruun-urt
# Processing Record for city: biak
# Processing Record for city: bolu
# Processing Record for city: manado
# Processing Record for city: agirish
# Processing Record for city: tracy
# Processing Record for city: obidos
# Processing Record for city: sisimiut
# Processing Record for city: nome
# Processing Record for city: praya
# Processing Record for city: kimbe
# Processing Record for city: witu
# Processing Record for city: sao filipe
# Processing Record for city: wajima
# Processing Record for city: san juan
# Processing Record for city: klaksvik
# Processing Record for city: ketchikan
# Processing Record for city: gubkinskiy
# Processing Record for city: malakal
# Processing Record for city: phrai bung
# Processing Record for city: vyazma
# Processing Record for city: igarape-miri
# Processing Record for city: tiruchchendur
# Processing Record for city: alice springs
# Processing Record for city: platteville
# Processing Record for city: sao joao da barra
# Processing Record for city: mayo
# Processing Record for city: bara
# Processing Record for city: amalapuram
# Processing Record for city: taybad
# Processing Record for city: merauke
# Processing Record for city: viedma
# Processing Record for city: uchiza
# Processing Record for city: juneau
# Processing Record for city: udachnyy
# Processing Record for city: paamiut
# Processing Record for city: bulgan
# Processing Record for city: milkovo
# Processing Record for city: esna
# Processing Record for city: businga
# Processing Record for city: cozumel
# Processing Record for city: ngukurr
# Processing Record for city: srednekolymsk
# Processing Record for city: boende
# Processing Record for city: takoradi
# Processing Record for city: skalistyy
# Processing Record for city: bolungarvik
# Processing Record for city: gayeri
# Processing Record for city: college
# Processing Record for city: danilovka
# Processing Record for city: san patricio
# Processing Record for city: kattivakkam
# Processing Record for city: mount pleasant
# Processing Record for city: solnechnyy
# Processing Record for city: iquitos
# Processing Record for city: astoria
# Processing Record for city: barguzin
# Processing Record for city: deputatskiy
# Processing Record for city: tura
# Processing Record for city: tumannyy
# Processing Record for city: hohhot
# Processing Record for city: zambezi
# Processing Record for city: grand gaube
# Processing Record for city: kingseat
# Processing Record for city: fereydun kenar
# Processing Record for city: northam
# Processing Record for city: geraldton
# Processing Record for city: namatanai
# Processing Record for city: altamira
# Processing Record for city: mentok
# Processing Record for city: derzhavinsk
# Processing Record for city: ugep
# Processing Record for city: dolbeau
# Processing Record for city: broome
# Processing Record for city: san miguel
# Processing Record for city: lar
# Processing Record for city: xacmaz
# Processing Record for city: tuktoyaktuk
# Processing Record for city: callaway
# Processing Record for city: muros
# Processing Record for city: sitka
# Processing Record for city: chilca
# Processing Record for city: mocambique
# Processing Record for city: darovskoy
# Processing Record for city: saleaula
# Processing Record for city: salalah
# Processing Record for city: malangwa
# Processing Record for city: thompson
# Processing Record for city: mys shmidta
# Processing Record for city: itoman
# Processing Record for city: chitipa
# Processing Record for city: severo-kurilsk
# Processing Record for city: nuuk
# Processing Record for city: port macquarie
# Processing Record for city: nouadhibou
# Processing Record for city: mweka
# Processing Record for city: norman wells
# Processing Record for city: sakakah
# Processing Record for city: kardla
# Processing Record for city: uyutne
# Processing Record for city: toliary
# Processing Record for city: parauna
# Processing Record for city: asyut
# Processing Record for city: fenoarivo atsinanana
# Processing Record for city: kavaratti
# Processing Record for city: shiyan
# Processing Record for city: sorong
# Processing Record for city: pemangkat
# Processing Record for city: vanino
# Processing Record for city: cedar city
# Processing Record for city: urucui
# Processing Record for city: santa cruz
# Processing Record for city: sao felix do xingu
# Processing Record for city: kangaatsiaq
# Processing Record for city: hadishahr
# Processing Record for city: lapua
# Processing Record for city: dubbo
# Processing Record for city: valdivia
# Processing Record for city: kununurra
# Processing Record for city: port augusta
# Processing Record for city: lazaro cardenas
# Processing Record for city: aswan
# Processing Record for city: brae
# Processing Record for city: natal
# Processing Record for city: ponta do sol
# Processing Record for city: pishin
# Processing Record for city: namibe
# Processing Record for city: west plains
# Processing Record for city: terra boa
# Processing Record for city: viligili
# Processing Record for city: kuruman
# Processing Record for city: camabatela
# Processing Record for city: greytown
# Processing Record for city: chara
# Processing Record for city: gamba
# Processing Record for city: caledon
# Processing Record for city: vaitupu
# Processing Record for city: denpasar
# Processing Record for city: jardim
# Processing Record for city: luena
# Processing Record for city: sao jose da coroa grande
# Processing Record for city: dana point
# Processing Record for city: taywarah
# Processing Record for city: turayf
# Processing Record for city: kolpashevo
# Processing Record for city: ferrol
# Processing Record for city: susa
# Processing Record for city: sangmelima
# Processing Record for city: salinas
# Processing Record for city: ina
# Processing Record for city: magistralnyy
# Processing Record for city: catamarca
# Processing Record for city: puro
# Processing Record for city: miri
# Processing Record for city: havoysund
# Processing Record for city: geresk
# Processing Record for city: yumen
# Processing Record for city: dong hoi
# Processing Record for city: karpogory
# Processing Record for city: xaltepec
# Processing Record for city: peniche
# Processing Record for city: leh
# Processing Record for city: bangassou
# Processing Record for city: walvis bay
# Processing Record for city: marsh harbour
# Processing Record for city: osakarovka
# Processing Record for city: moerai
# Processing Record for city: puga
# Processing Record for city: sidi qasim
# Processing Record for city: virginia beach
# Processing Record for city: ko samui
# Processing Record for city: oktyabrskoye
# Processing Record for city: varkkallai
# Processing Record for city: mnogovershinnyy
# Processing Record for city: trinidad
# Processing Record for city: cabatuan
# Processing Record for city: jumla
# Processing Record for city: turukhansk
# Processing Record for city: rio gallegos
# Processing Record for city: nanchang
# Processing Record for city: tooele
# Processing Record for city: ritchie
# Processing Record for city: kondinskoye
# Processing Record for city: auki
# Processing Record for city: esperance
# Processing Record for city: soyo
# Processing Record for city: matay
# Processing Record for city: sable-sur-sarthe
# Processing Record for city: planaltina
# Processing Record for city: palu
# Processing Record for city: steinbach
# Processing Record for city: porto torres
# Processing Record for city: kidal
# Processing Record for city: creston
# Processing Record for city: lakhimpur
# Processing Record for city: barkot
# Processing Record for city: chambersburg
# Processing Record for city: nueve de julio
# Processing Record for city: san policarpo
# Processing Record for city: gorontalo
# Processing Record for city: pilar
# Processing Record for city: gizo
# Processing Record for city: goderich
# Processing Record for city: saldanha
# Processing Record for city: phan thiet
# Processing Record for city: dingle
# Processing Record for city: hami
# Processing Record for city: moa
# Processing Record for city: kitimat
# Processing Record for city: boralday
# Processing Record for city: chemal
# Processing Record for city: richards bay
# Processing Record for city: leningradskiy
# Processing Record for city: oussouye
# Processing Record for city: shatalovo
# Processing Record for city: burns lake
# Processing Record for city: meyungs
# Processing Record for city: maniitsoq
# Processing Record for city: madang
# Processing Record for city: albury
# Processing Record for city: samusu
# Processing Record for city: kollam
# Processing Record for city: turtas
# Processing Record for city: portlethen
# Processing Record for city: consolacion del sur
# Processing Record for city: andenes
# Processing Record for city: nizhneyansk
# Processing Record for city: sertania
# Processing Record for city: talara
# Processing Record for city: ardistan
# Processing Record for city: luanda
# Processing Record for city: srandakan
# Processing Record for city: nabire
# Processing Record for city: jining
# Processing Record for city: curvelo
# Processing Record for city: mae sai
# Processing Record for city: shingu
# Processing Record for city: laguna
# Processing Record for city: sistranda
# Processing Record for city: dicabisagan
# Processing Record for city: crailsheim
# Processing Record for city: crossville
# Processing Record for city: kupang
# Processing Record for city: mitsamiouli
# Processing Record for city: znamenskoye
# Processing Record for city: kushima
# Processing Record for city: huilong
# Processing Record for city: abu samrah
# Processing Record for city: chagda
# Processing Record for city: opuwo
# Processing Record for city: charters towers
# Processing Record for city: primorsko
# Processing Record for city: ostrovnoy
# Processing Record for city: whitehorse
# Processing Record for city: warrington
# Processing Record for city: kenai
# Processing Record for city: banmo
# Processing Record for city: izumo
# Processing Record for city: tual
# Processing Record for city: ust-kamchatsk
# Processing Record for city: bachaquero
# Processing Record for city: wenling
# Processing Record for city: achisay
# Processing Record for city: illapel
# Processing Record for city: maldonado
# Processing Record for city: flin flon
# Processing Record for city: powell river
# Processing Record for city: barcelos
# Processing Record for city: haibowan
# Processing Record for city: sur
# Processing Record for city: dukat
# Processing Record for city: nadym
# Processing Record for city: puerto maldonado
# Processing Record for city: zemetchino
# Processing Record for city: rupert
# Processing Record for city: bonthe
# Processing Record for city: basco
# Processing Record for city: la rioja
# Processing Record for city: port keats
# Processing Record for city: lokhvytsya
# Processing Record for city: dongfeng
# Processing Record for city: neiafu
# Processing Record for city: sinnamary
# Processing Record for city: shitanjing
# Processing Record for city: jiaocheng
# Processing Record for city: trairi
# Processing Record for city: half moon bay

# %%
# Confirm json pull was successful then comment out to take less space. 
#responses_city

# %% [markdown]
# ### Convert to DataFrame

# %%
# Create new lists to create dataframe with needed data
lat = []
lng = []
temp = []
hum = []
cloud = []
wind_speed = []
city_name = []
country_name = []
main_url = "http://api.openweathermap.org/data/2.5/weather?"
query_url = f"{main_url}appid={weather_key}&q="

# Fill new lists

for city in cities:
    city_data = requests.get(query_url + city).json()

    try:
        city_name.append(city_data['name'])
        country_name.append(city_data['sys']['country'])
        lat.append(city_data['coord']['lat'])
        lng.append(city_data['coord']['lon'])
        temp.append(city_data['main']['temp_max'])
        hum.append(city_data['main']['humidity'])
        cloud.append(city_data['clouds']['all'])
        wind_speed.append(city_data['wind']['speed'])
    
    except KeyError:
        pass

# %%
# Create data frame with compiled data
city_data_df = pd.DataFrame({'City': city_name, 'Country': country_name, 'Lat': lat, 'Lng': lng, 'Max Temp': temp, 'Humidity %': hum, 
                         'Cloudiness': cloud, 'Wind Speed': wind_speed})
city_data_df.index.name = 'City_ID'
city_data_df
# Out:
#                          City Country      Lat       Lng  Max Temp  \
# City_ID
# 0                   Toowoomba      AU -27.5500  151.9667    294.15
# 1               Victor Harbor      AU -35.5667  138.6167    292.59
# 2        Formosa do Rio Preto      BR -11.0483  -45.1931    298.57
# 3                       Kapaa      US  22.0752 -159.3190    293.15
# 4                      Arman'      RU  59.7000  150.1667    256.35
# ...                       ...     ...      ...       ...       ...
# 578                 Sinnamary      GF   5.3833  -52.9500    299.72
# 579                Shitanjing      CN  39.2342  106.3439    270.00
# 580                 Jiaocheng      CN  24.6774  116.1389    293.26
# 581                    Trairi      BR  -3.2778  -39.2689    303.80
# 582             Half Moon Bay      US  37.4636 -122.4286    282.59
#
#          Humidity %  Cloudiness  Wind Speed
# City_ID
# 0                83          40        4.63
# 1                73          35        2.75
# 2                79         100        1.95
# 3                83          90        8.75
# 4                78           0        1.44
# ...             ...         ...         ...
# 578              78          42        4.00
# 579              26           0        4.84
# 580              80           4        1.80
# 581              60           2        3.63
# 582              87          75        3.09
#
# [583 rows x 8 columns]

# %%
# Export data to csv
city_data_df.to_csv("../output_data/cities.csv", encoding="utf-8", header=True)

# %% [markdown]
# ## Lattitude vs. Temperature Plot

# %%
# Create scatter plot of results for Temperature
plt.scatter(lat, temp)
plt.xlabel("Lattitude")
plt.ylabel("Max Temperature")
plt.title("Lattitude vs. Temperature")
plt.savefig("../output_data/Fig1.png")
plt.show()

# %% [markdown]
# The results from the data show that temperature is highest the closer to equator (0 Lattitude). At Lattitude 80 which is the furthest from the equator and closest to the top of the northern hemisphere we see the temperature dropping to the lowest kelvin amount.

# %%
plt.scatter(lat, hum, facecolors='red')
plt.xlabel("Lattitude")
plt.ylabel ("% Humidity")
plt.title("Relation between latitude and humidity")
plt.savefig("../output_data/Fig2.png")
plt.show()
